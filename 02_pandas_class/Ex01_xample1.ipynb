# %% [markdown]
#  ## 미국 대통령 신장(키) 데이타를 분석
#
#
#         ` 전체적인 기본 통계량
#         ` 평균신장
#         ` 그래프로 시각화

# %%
import pandas as pd

data = pd.read_csv('data/president_heights.csv')

data.head()
data.tail()
# Out:
#     order               name  height(cm)
# 37     40      Ronald Reagan         185
# 38     41  George H. W. Bush         188
# 39     42       Bill Clinton         188
# 40     43     George W. Bush         182
# 41     44       Barack Obama         185

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order       42 non-null     int64
#  1   name        42 non-null     object
#  2   height(cm)  42 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
data.describe()

data.mean()

data.std()

data.min()

data.max()
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_9500\3565713303.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_9500\3565713303.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# order                     44
# name          Zachary Taylor
# height(cm)               193
# dtype: object

# %%
# data['height(cm)']
data.columns = ['no','name','height']
data.height
# Out:
# 0     189
# 1     170
# 2     189
# 3     163
# 4     183
# 5     171
# 6     185
# 7     168
# 8     173
# 9     183
# 10    173
# 11    173
# 12    175
# 13    178
# 14    183
# 15    193
# 16    178
# 17    173
# 18    174
# 19    183
# 20    183
# 21    168
# 22    170
# 23    178
# 24    182
# 25    180
# 26    183
# 27    178
# 28    182
# 29    188
# 30    175
# 31    179
# 32    183
# 33    193
# 34    182
# 35    183
# 36    177
# 37    185
# 38    188
# 39    188
# 40    182
# 41    185
# Name: height, dtype: int64

# %%
data.height.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['height'])
# Out:
# (array([ 1.,  2.,  3.,  5.,  3.,  6., 12.,  3.,  5.,  2.]),
#  array([163., 166., 169., 172., 175., 178., 181., 184., 187., 190., 193.]),
#  <BarContainer object of 10 artists>)
