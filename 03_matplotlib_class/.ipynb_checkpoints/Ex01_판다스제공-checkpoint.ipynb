# %% [markdown]
# ### 1. Series 의 plot()

# %%
# %matplotlib inline

# %%
from pandas import Series

# %%
# 판다스 그래프 : Series의 plot() 
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
s
s.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %%
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
splot = s.plot(kind='bar')
splot.set_xlabel('데이터')
splot.set_ylabel('수치')
splot.set_title('샘플데이터')
# Out:
# Text(0.5, 1.0, '제목')

# %% [markdown]
# ## 2. DataFrame 그래프

# %%
from pandas import DataFrame
import numpy as np

# 데이타프레임에서 시각화 작업
df=DataFrame(np.random.randn(10, 4),    # 난수 10개를 4번
             columns=['level','step','cnt','temp'], 
             index=np.arange(0,100,10))     # np.arange(0,100,10)
df
# Out:
#        level      step       cnt      temp
# 0   0.750704 -1.980588 -0.082470 -1.082521
# 10  0.935174  0.358811 -1.639381 -0.284727
# 20 -0.947456 -0.015206  1.849909 -0.742656
# 30 -0.436355  0.834127 -1.119099 -0.147222
# 40 -0.417205 -0.246550 -0.034614  0.013461
# 50 -0.066139 -2.731641 -0.440973 -0.071860
# 60 -0.528521  0.535586 -0.212305  0.642356
# 70  0.042458  0.006852 -0.564506  1.142174
# 80  0.447217 -0.733894 -0.858689 -0.944402
# 90  0.714837 -0.348039 -0.093114 -0.480708

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# [참고] 데이타사이언스스쿨 > Pandas의 시각화 기능
#
# https://datascienceschool.net/view-notebook/372443a5d90a46429c6459bba8b4342c/
